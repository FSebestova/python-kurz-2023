# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
platy = pd.read_csv("platy_2021_02.csv")
platy = platy.drop(platy.columns[0], axis=1)
platy.head()
# Out:
#       plat
# 0  54900.0
# 1  54800.0
# 2  36400.0
# 3  47900.0
# 4  34200.0

# %%
platy.hist()
# Out:
# array([[<Axes: title={'center': 'plat'}>]], dtype=object)

# %%
platy.hist(bins=7, rwidth = 0.75, facecolor = "red")
plt.title("Platy únor 2021\n\n")
plt.xlabel('Plat v Kč')
plt.ylabel('Zaměstnanci')
# Out:
# Text(0, 0.5, 'Zaměstnanci')
